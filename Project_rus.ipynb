# %% [markdown]
# # Подключение нужных библиотек и загрузка данных

# %%
import pandas as pd
import seaborn as sns
import numpy as np
import plotly.express as px
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('Lung_cancer.csv')

# %%
def set_size():
    plt.figure(figsize=(20,7))

# %% [markdown]
# # Переименование столбцов

# %%
df = df.rename(columns = {'GENDER' : 'ПОЛ', 'AGE':'ВОЗРАСТ', 'SMOKING':'КУРЕНИЕ', 'YELLOW_FINGERS':'ЖЕЛТЫЕ ПАЛЬЦЫ', 
                     'ANXIETY':'ТРЕВОЖНОСТЬ', 'PEER_PRESSURE':'ДАВЛЕНИЕ СО СТОРОНЫ ОКРУЖАЮЩИХ',
                     'CHRONIC DISEASE':'ХРОНИЧЕСКИЕ ЗАБОЛЕВАНИЯ', 'FATIGUE ':'УСТАЛОСТЬ', 'ALLERGY ':'АЛЛЕРГИЯ',
                     'WHEEZING':'ХРИП', 'ALCOHOL CONSUMING':'АЛКОГОЛИЗМ', 'COUGHING':'КАШЕЛЬ', 
                     'SHORTNESS OF BREATH':'ОДЫШКА', 'SWALLOWING DIFFICULTY':'ЗАТРУДНЕНИЕ ГЛОТАНИЯ',
                     'CHEST PAIN':'БОЛЬ В СПИНЕ', 'LUNG_CANCER':'РАК ЛЕГКИХ'})

# %% [markdown]
# # Анализ данных

# %%
df.head()
# Out:
#   ПОЛ  ВОЗРАСТ  КУРЕНИЕ  ЖЕЛТЫЕ ПАЛЬЦЫ  ТРЕВОЖНОСТЬ  \
# 0   M       69        1              2            2
# 1   M       74        2              1            1
# 2   F       59        1              1            1
# 3   M       63        2              2            2
# 4   F       63        1              2            1
#
#    ДАВЛЕНИЕ СО СТОРОНЫ ОКРУЖАЮЩИХ  ХРОНИЧЕСКИЕ ЗАБОЛЕВАНИЯ  УСТАЛОСТЬ  \
# 0                               1                        1          2
# 1                               1                        2          2
# 2                               2                        1          2
# 3                               1                        1          1
# 4                               1                        1          1
#
#    АЛЛЕРГИЯ  ХРИП  АЛКОГОЛИЗМ  КАШЕЛЬ  ОДЫШКА  ЗАТРУДНЕНИЕ ГЛОТАНИЯ  \
# 0         1     2           2       2       2                     2
# 1         2     1           1       1       2                     2
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 309 entries, 0 to 308
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   ПОЛ                             309 non-null    object
#  1   ВОЗРАСТ                         309 non-null    int64
#  2   КУРЕНИЕ                         309 non-null    int64
#  3   ЖЕЛТЫЕ ПАЛЬЦЫ                   309 non-null    int64
#  4   ТРЕВОЖНОСТЬ                     309 non-null    int64
#  5   ДАВЛЕНИЕ СО СТОРОНЫ ОКРУЖАЮЩИХ  309 non-null    int64
#  6   ХРОНИЧЕСКИЕ ЗАБОЛЕВАНИЯ         309 non-null    int64
#  7   УСТАЛОСТЬ                       309 non-null    int64
#  8   АЛЛЕРГИЯ                        309 non-null    int64
#  9   ХРИП                            309 non-null    int64
#  10  АЛКОГОЛИЗМ                      309 non-null    int64
#  11  КАШЕЛЬ                          309 non-null    int64
# ...

# %%
df.describe(include='all')
# Out:
#         ПОЛ     ВОЗРАСТ     КУРЕНИЕ  ЖЕЛТЫЕ ПАЛЬЦЫ  ТРЕВОЖНОСТЬ  \
# count   309  309.000000  309.000000     309.000000   309.000000
# unique    2         NaN         NaN            NaN          NaN
# top       M         NaN         NaN            NaN          NaN
# freq    162         NaN         NaN            NaN          NaN
# mean    NaN   62.673139    1.563107       1.569579     1.498382
# std     NaN    8.210301    0.496806       0.495938     0.500808
# min     NaN   21.000000    1.000000       1.000000     1.000000
# 25%     NaN   57.000000    1.000000       1.000000     1.000000
# 50%     NaN   62.000000    2.000000       2.000000     1.000000
# 75%     NaN   69.000000    2.000000       2.000000     2.000000
# max     NaN   87.000000    2.000000       2.000000     2.000000
#
#         ДАВЛЕНИЕ СО СТОРОНЫ ОКРУЖАЮЩИХ  ХРОНИЧЕСКИЕ ЗАБОЛЕВАНИЯ   УСТАЛОСТЬ  \
# count                       309.000000               309.000000  309.000000
# ...

# %%
df.isnull().sum()
# Out:
# ПОЛ                               0
# ВОЗРАСТ                           0
# КУРЕНИЕ                           0
# ЖЕЛТЫЕ ПАЛЬЦЫ                     0
# ТРЕВОЖНОСТЬ                       0
# ДАВЛЕНИЕ СО СТОРОНЫ ОКРУЖАЮЩИХ    0
# ХРОНИЧЕСКИЕ ЗАБОЛЕВАНИЯ           0
# УСТАЛОСТЬ                         0
# АЛЛЕРГИЯ                          0
# ХРИП                              0
# АЛКОГОЛИЗМ                        0
# КАШЕЛЬ                            0
# ОДЫШКА                            0
# ЗАТРУДНЕНИЕ ГЛОТАНИЯ              0
# БОЛЬ В СПИНЕ                      0
# РАК ЛЕГКИХ                        0
# dtype: int64

# %% [markdown]
# Нулевых значений нет

# %% [markdown]
# # Обработка данных

# %%
duplicates = df[df.duplicated()].shape[0]
df.drop_duplicates(keep='first', inplace=True)

# %%
for column in df.columns:
    df[column] = df[column].replace(1, 0)
    df[column] = df[column].replace(2, 1)

# %%
for column in df.columns:
    df[column] = df[column].replace('YES', 1)
    df[column] = df[column].replace('NO', 0)

# %%
df['ПОЛ'] = df['ПОЛ'].replace('M', 0)
df['ПОЛ'] = df['ПОЛ'].replace('F', 1)

# %%
df_gr = df.copy()
for column in df_gr.columns:
    df_gr[column] = df_gr[column].replace(1, 'YES')
    df_gr[column] = df_gr[column].replace(0, 'NO')
df_gr['ПОЛ'] = df_gr['ПОЛ'].replace({'NO': 'MALE', 'YES': 'FEMALE'})

# %%
df_pos = df_gr[df_gr['РАК ЛЕГКИХ'] == 'YES'] 
df_neg = df_gr[df_gr['РАК ЛЕГКИХ'] == 'NO']

# %% [markdown]
# # Визуализация данных

# %%
_, axs = plt.subplots(2,1,figsize=(20,12), sharex=True, sharey=True)
plt.tight_layout(pad=5.0)

sns.histplot(data = df_pos[df_pos['ПОЛ'] == 'MALE']['ВОЗРАСТ'], color='brown', bins=20, ax = axs[0], kde=True)
axs[0].set_title("\nЗаболевания раком легких у мужчин \n", fontsize=24)
axs[0].set_xlabel('Возраст', fontsize=15)
axs[0].set_ylabel('Количество', fontsize=15)

sns.histplot(df_pos[df_pos['ПОЛ'] == 'FEMALE']['ВОЗРАСТ'], color='green', bins=20, ax = axs[1], kde=True)
axs[1].set_title("\nЗаболевания раком легких у женщин\n", fontsize=24)
axs[1].set_xlabel('Возраст', fontsize=15)
axs[1].set_ylabel('Количество', fontsize=15)
# Out:
# Text(153.0, 0.5, 'Количество')

# %%
_, axs = plt.subplots(1,2,figsize=(20,8), sharex=True, sharey=True)
plt.tight_layout(pad=4.0)


sns.countplot(data = df_pos, x='ПОЛ', hue='КУРЕНИЕ', hue_order=['YES', 'NO'], palette = 'terrain', ax = axs[0])
axs[0].set_title("Эффект от курения\n", fontsize=30)
axs[0].set_xlabel('Пол', fontsize=15)
axs[0].set_ylabel('Количество', fontsize=15)

sns.countplot(data = df_pos, x='ПОЛ', hue='АЛКОГОЛИЗМ', hue_order=['YES', 'NO'], palette = 'terrain', ax = axs[1])
axs[1].set_title("\nЭффект от принятия алкоголя\n", fontsize=30)
axs[1].set_xlabel('Пол', fontsize=15)
axs[1].set_ylabel('Количество', fontsize=15)
# Out:
# Text(784.7272727272725, 0.5, 'Количество')

# %%
_, axs = plt.subplots(2,5,figsize=(20,14), sharex=True, sharey=True)
plt.tight_layout(pad=4.0)

sns.countplot(data = df_pos, x='ПОЛ', hue='ЖЕЛТЫЕ ПАЛЬЦЫ', hue_order=['YES', 'NO'], palette = 'terrain', ax = axs[0,0])
axs[0,0].set_xlabel('Пол')
axs[0,0].set_ylabel('Количество')

sns.countplot(data = df_pos, x='ПОЛ', hue='ТРЕВОЖНОСТЬ', hue_order=['YES', 'NO'], palette = 'terrain', ax = axs[0,1])
axs[0,1].set_xlabel('Пол')
axs[0,1].set_ylabel('Количество')

sns.countplot(data = df_pos, x='ПОЛ', hue='ДАВЛЕНИЕ СО СТОРОНЫ ОКРУЖАЮЩИХ', hue_order=['YES', 'NO'], palette = 'terrain', ax = axs[0,2])
axs[0,2].set_xlabel('Пол')
axs[0,2].set_ylabel('Количество')

sns.countplot(data = df_pos, x='ПОЛ', hue='ХРОНИЧЕСКИЕ ЗАБОЛЕВАНИЯ', hue_order=['YES', 'NO'], palette = 'terrain', ax = axs[0,3])
axs[0,3].set_xlabel('Пол')
axs[0,3].set_ylabel('Количество')

sns.countplot(data = df_pos, x='ПОЛ', hue='УСТАЛОСТЬ', hue_order=['YES', 'NO'], palette = 'terrain', ax = axs[0,4])
axs[0,4].set_xlabel('Пол')
axs[0,4].set_ylabel('Количество')

sns.countplot(data = df_pos, x='ПОЛ', hue='АЛЛЕРГИЯ', hue_order=['YES', 'NO'], palette = 'terrain', ax = axs[1,0])
axs[1,0].set_xlabel('Пол')
axs[1,0].set_ylabel('Количество')

sns.countplot(data = df_pos, x='ПОЛ', hue='ХРИП', hue_order=['YES', 'NO'], palette = 'terrain', ax = axs[1,1])
axs[1,1].set_xlabel('Пол')
axs[1,1].set_ylabel('Количество')

sns.countplot(data = df_pos, x='ПОЛ', hue='КАШЕЛЬ', hue_order=['YES', 'NO'], palette = 'terrain', ax = axs[1,2])
axs[1,2].set_xlabel('Пол')
axs[1,2].set_ylabel('Количество')

sns.countplot(data = df_pos, x='ПОЛ', hue='ОДЫШКА', hue_order=['YES', 'NO'], palette = 'terrain', ax = axs[1,3])
axs[1,3].set_xlabel('Пол')
axs[1,3].set_ylabel('Количество')

sns.countplot(data = df_pos, x='ПОЛ', hue='ЗАТРУДНЕНИЕ ГЛОТАНИЯ', hue_order=['YES', 'NO'], palette = 'terrain', ax = axs[1,4])
axs[1,4].set_xlabel('Пол')
axs[1,4].set_ylabel('Количество')
# Out:
# Text(1099.5862068965519, 0.5, 'Количество')

# %%
plt.subplots(figsize =(20, 15))
plt.tight_layout(pad=4.0)
sns.heatmap(df.corr(), annot=True, vmin=-1, linewidths=0.1, cmap='terrain')
plt.title('Матрица корреляций', fontsize=24)

plt.show()

# %% [markdown]
# # Чистка данных

# %%
df.isnull().sum()
# Out:
# ПОЛ                               0
# ВОЗРАСТ                           0
# КУРЕНИЕ                           0
# ЖЕЛТЫЕ ПАЛЬЦЫ                     0
# ТРЕВОЖНОСТЬ                       0
# ДАВЛЕНИЕ СО СТОРОНЫ ОКРУЖАЮЩИХ    0
# ХРОНИЧЕСКИЕ ЗАБОЛЕВАНИЯ           0
# УСТАЛОСТЬ                         0
# АЛЛЕРГИЯ                          0
# ХРИП                              0
# АЛКОГОЛИЗМ                        0
# КАШЕЛЬ                            0
# ОДЫШКА                            0
# ЗАТРУДНЕНИЕ ГЛОТАНИЯ              0
# БОЛЬ В СПИНЕ                      0
# РАК ЛЕГКИХ                        0
# dtype: int64

# %%
df.describe(include='all')
# Out:
#               ПОЛ     ВОЗРАСТ     КУРЕНИЕ  ЖЕЛТЫЕ ПАЛЬЦЫ  ТРЕВОЖНОСТЬ  \
# count  276.000000  276.000000  276.000000     276.000000   276.000000
# mean     0.485507   62.909420    0.543478       0.576087     0.496377
# std      0.500698    8.379355    0.499011       0.495075     0.500895
# min      0.000000   21.000000    0.000000       0.000000     0.000000
# 25%      0.000000   57.750000    0.000000       0.000000     0.000000
# 50%      0.000000   62.500000    1.000000       1.000000     0.000000
# 75%      1.000000   69.000000    1.000000       1.000000     1.000000
# max      1.000000   87.000000    1.000000       1.000000     1.000000
#
#        ДАВЛЕНИЕ СО СТОРОНЫ ОКРУЖАЮЩИХ  ХРОНИЧЕСКИЕ ЗАБОЛЕВАНИЯ   УСТАЛОСТЬ  \
# count                      276.000000               276.000000  276.000000
# mean                         0.507246                 0.521739    0.663043
# std                          0.500856                 0.500435    0.473529
# ...

# %% [markdown]
# ### Как можно увидеть, пропусков и выбросов в датасете нет, поэтому данный этап можно пропустить

# %% [markdown]
# # Обучение модели

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier

# %%
target = df['РАК ЛЕГКИХ']
predictors = df.drop(['РАК ЛЕГКИХ'], axis=1)
x_train, x_test, y_train, y_test = train_test_split(predictors, target, test_size=0.7, random_state=0)

# %%
lg = LogisticRegression()
lg.fit(x_train, y_train)
y_pred = lg.predict(x_test)
score_lg = round(accuracy_score(y_pred, y_test) * 100, 2)
print(score_lg)
# Out:
# 91.75

# %%
dt = DecisionTreeClassifier()
dt.fit(x_train, y_train)
y_pred = dt.predict(x_test)
score_dt = round(accuracy_score(y_pred, y_test) * 100, 2)
print(score_dt)
# Out:
# 86.6

# %%
rf = RandomForestClassifier()
rf.fit(x_train, y_train)
y_pred = rf.predict(x_test)
score_rf = round(accuracy_score(y_pred, y_test) * 100, 2)
print(score_rf)
# Out:
# 90.21

# %%
models = pd.DataFrame({'Модель': ['LogisticRegression', 'DecisionTreeClassifier', 'RandomForestClassifier'],
                      'Счет(в процентах)': [score_lg, score_dt, score_rf]})

# %%
models.sort_values(by='Счет(в процентах)', ascending=False)
# Out:
#                    Модель  Счет(в процентах)
# 0      LogisticRegression              91.75
# 2  RandomForestClassifier              90.21
# 1  DecisionTreeClassifier              86.60
